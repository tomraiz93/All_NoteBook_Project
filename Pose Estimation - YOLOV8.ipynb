# %% [markdown]
# <a href="https://colab.research.google.com/github/tomraiz93/aespa/blob/main/Pose%20Estimation%20-%20YOLOV8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.228 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.3/107.7 GB disk)

# %%
from ultralytics import YOLO

model = YOLO('yolov8n-pose.pt')
source = 'https://ultralytics.com/images/bus.jpg'
model.predict(source,save=True,imgsz=640,conf=0.5)
# Out:
# ...
# 100%|██████████| 6.51M/6.51M [00:00<00:00, 234MB/s]
# ...
# 100%|██████████| 476k/476k [00:00<00:00, 66.1MB/s]
# image 1/1 /content/bus.jpg: 640x480 3 persons, 339.9ms
# Speed: 26.1ms preprocess, 339.9ms inference, 38.0ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/pose/predict
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: ultralytics.engine.results.Keypoints object
#  masks: None
#  names: {0: 'person'}
#  orig_img: array([[[122, 148, 172],
#          [120, 146, 170],
#          [125, 153, 177],
#          ...,
#          [157, 170, 184],
#          [158, 171, 185],
#          [158, 171, 185]],
#
#         [[127, 153, 177],
#          [124, 150, 174],
#          [127, 155, 179],
#          ...,
#          [158, 171, 185],
#          [159, 172, 186],
#          [159, 172, 186]],
#
#         [[128, 154, 178],
#          [126, 152, 176],
#          [126, 154, 178],
#          ...,
# ...

# %%
#Trainning
# !yolo train model=yolov8n-pose.pt data="/content/coco8-pose.yaml" epochs=3 imgsz=640
# Out:
# Ultralytics YOLOv8.0.228 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
# !yolo predict model=yolov8n-pose.pt source="https://media.roboflow.com/notebooks/examples/dog.jpeg"
# Out:
# Ultralytics YOLOv8.0.228 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8n-pose summary (fused): 187 layers, 3289964 parameters, 0 gradients, 9.2 GFLOPs
#
# ...
# 100% 104k/104k [00:00<00:00, 64.1MB/s]
# image 1/1 /content/dog.jpeg: 640x384 2 persons, 213.5ms
# Speed: 12.4ms preprocess, 213.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Đường dẫn đến ảnh
image_path = '/content/runs/pose/predict2/dog.jpeg'

# Đọc ảnh
image = mpimg.imread(image_path)

# Hiển thị ảnh
plt.imshow(image)import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Đường dẫn đến ảnh
image_path = '/content/runs/pose/predict2/dog.jpeg'

# Đọc ảnh
image = mpimg.imread(image_path)

# Hiển thị ảnh
plt.imshow(image)
plt.axis('off')
plt.show()
plt.axis('off')
plt.show()

# %%
'''
import cv2
from ultralytics import YOLO

model = YOLO('yolov8n-pose.pt')

video_path = 0
cap = cv2.VideoCapture(video_path)

while cap.isOpened():
  success, frame = cap.read()

  if success:
    results = model.predict(source=frame,save=True)

    amotated_frame = results[0].plot()
    cv2.imshow('YOLOv8 Inference',amotated_frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
      break
  else:
    break

cap.release()
cv2.destroyAllWindows()
'''

# %%
from ultralytics import YOLO
model = YOLO('yolov8n-pose.pt')
model.predict(source,save=True,imgsz=640,conf=0.5)
# Out:
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 /content/bus.jpg: 640x480 3 persons, 320.6ms
# Speed: 15.1ms preprocess, 320.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/pose/predict3
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: ultralytics.engine.results.Keypoints object
#  masks: None
#  names: {0: 'person'}
#  orig_img: array([[[122, 148, 172],
#          [120, 146, 170],
#          [125, 153, 177],
#          ...,
#          [157, 170, 184],
#          [158, 171, 185],
#          [158, 171, 185]],
#
#         [[127, 153, 177],
#          [124, 150, 174],
#          [127, 155, 179],
#          ...,
#          [158, 171, 185],
#          [159, 172, 186],
#          [159, 172, 186]],
#
#         [[128, 154, 178],
#          [126, 152, 176],
#          [126, 154, 178],
#          ...,
#          [158, 171, 185],
# ...

# %%
# !yolo predict model=yolov8n-pose.pt source="https://images2.thanhnien.vn/528068263637045248/2023/7/29/trinity-rodman--16905982481611503557824.jpeg"
# Out:
# Ultralytics YOLOv8.0.228 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8n-pose summary (fused): 187 layers, 3289964 parameters, 0 gradients, 9.2 GFLOPs
#
# ...
# 100% 127k/127k [00:00<00:00, 197kB/s]
# image 1/1 /content/trinity-rodman--16905982481611503557824.jpeg: 448x640 11 persons, 241.3ms
# Speed: 9.9ms preprocess, 241.3ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/pose/predict4
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Đường dẫn đến ảnh
image_path = '/content/runs/pose/predict4/trinity-rodman--16905982481611503557824.jpeg'

# Đọc ảnh
image = mpimg.imread(image_path)

# Hiển thị ảnh
plt.imshow(image)
plt.axis('off')
plt.show()

# %%
# !yolo predict model=yolov8n-pose.pt source="football.mp4"
# Out:
# Ultralytics YOLOv8.0.228 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8n-pose summary (fused): 187 layers, 3289964 parameters, 0 gradients, 9.2 GFLOPs
#
# video 1/1 (1/649) /content/football.mp4: 640x384 2 persons, 206.5ms
# video 1/1 (2/649) /content/football.mp4: 640x384 2 persons, 144.4ms
# video 1/1 (3/649) /content/football.mp4: 640x384 2 persons, 140.0ms
# video 1/1 (4/649) /content/football.mp4: 640x384 2 persons, 126.6ms
# video 1/1 (5/649) /content/football.mp4: 640x384 2 persons, 134.0ms
# video 1/1 (6/649) /content/football.mp4: 640x384 2 persons, 140.2ms
# video 1/1 (7/649) /content/football.mp4: 640x384 2 persons, 143.6ms
# video 1/1 (8/649) /content/football.mp4: 640x384 2 persons, 148.4ms
# video 1/1 (9/649) /content/football.mp4: 640x384 2 persons, 156.0ms
# video 1/1 (10/649) /content/football.mp4: 640x384 2 persons, 144.0ms
# video 1/1 (11/649) /content/football.mp4: 640x384 2 persons, 159.1ms
# ...
